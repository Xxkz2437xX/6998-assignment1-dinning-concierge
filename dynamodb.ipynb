# %%
AKIATZIDTXBNSQBZ2PMD

cskyfVWPDFw6epFFyVB8tb5YwgqaH9HNo7pgdf+/

# %%
from __future__ import print_function
import csv
import pandas as pd
import time
import json

# %%
data=pd.read_csv('/Users/xxzkbxx/Desktop/yelp.csv')

# %%
data=data.drop_duplicates(subset=['Business_ID'])
data.reset_index(drop = True)
# Out:
#                  Business_ID                           Name  \
# 0     XsXLVWr1UZWVhKThNvNiaA                Blue Willow 夜来湘
# 1     BNaveJmi-OUGKG9sRfrIhA                        Mr. Sun
# 2     HduEOz0RSK91GDr8EoxELw             Shun Lee - 98th ST
# 3     EmJ7rfmv2y6lQZxgA8U__g      Red Peony Chinese Cuisine
# 4     bVkjBJlAIwKAj9Aw1KVWjA                 Dim Sum Palace
# ...                      ...                            ...
# 5040  2ua5kZUhVz25m7_iFOdwtQ  Yuki Hana Japanese Restaurant
# 5041  3sQPGzWl0PMi2ULZ4DbEAg                    Sushi Mambo
# 5042  G4qZvheX74VwYvek7I8iQg                       Buntopia
# 5043  gEfsayvqWqI2KfCF43TJ_A                   Port of Call
# 5044  bnCZgNyG9FRXRy7g2-rcMw         Yoshi Japanese cuisine
#
#                  Address                                        Coordinates  \
# 0           40 W 56th St    {'latitude': 40.76292, 'longitude': -73.976546}
# 1           48 W 48th St     {'latitude': 40.75809, 'longitude': -73.98026}
# ...

# %%
data.to_csv("/Users/xxzkbxx/Desktop/yelp.csv", index =False)

# %%
import boto3
import csv

# %%
# Get the service resource.
dynamodb = boto3.resource('dynamodb', region_name='us-east-1', aws_access_key_id='AKIATZIDTXBN5HMFSAWF', aws_secret_access_key='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')
# A low-level client representing Amazon DynamoDB
client = boto3.client('dynamodb', region_name='us-east-1')

# %%
table = dynamodb.Table('yelp')

# %%
print(table.item_count)
# Out:
# 0

# %%
with table.batch_writer() as batch:
    with open('/Users/xxzkbxx/Desktop/yelp.csv', encoding='UTF-8') as csvfile:
        reader = csv.reader(csvfile)
        #['Business_ID', 'Name', 'Address', 'Coordinates', 'Num_of_Reviews', 'Rating', 'Zip_Code', 'Cuisine']
        for row in reader:
            try:
                batch.put_item(
                Item={
                    'insertedAtTimestamp': time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()),
                    'cuisine': row[7],
                    'Business_ID': row[0],
                    'Name': row[1],
                    'Address': row[2],
                    'Coordinates': row[3],
                    'Num_of_Reviews':row[4],
                    'Rating':row[5],
                    'Zip_Code':row[6]
                })
            except:
                print(row)
